# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
jugadores = ["Pessi", "Penaldo", "DickMbappe", "Mi rubia Halaand", "MoniciJr",]
goles = [8, 3, 7,7,4]

plt.figure(figsize=(8,5))
plt.bar(jugadores, goles, color = ["Skyblue", "green", "black", "red", "yellow"])

plt.title("Goles de jugadores del Mundial 2026", fontsize=14, fontweight="bold")
plt.xlabel("Jugadores", fontsize= 12)
plt.ylabel("goles", fontsize= 12) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
